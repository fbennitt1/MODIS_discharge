# %%
import os
import time

import ee
import matplotlib.pyplot as plt
import math
import numpy as np
import pandas as pd
import xarray as xr
# from datetime import datetime, timedelta
# from scipy.io import savemat
# from scipy.io import loadmat as loadmat2
# from mat73 import loadmat
import h5py
# import hdf5storage

from multiprocessing import Pool

# %% [markdown]
# ### Functions

# %%
os.environ.get('SLURM_CPUS_PER_TASK')
# Out:
# '16'

# %%
# def selimage(nday, product1, product2, region, maskband, band, crs_mod, trans_mod):
#     image=ee.ImageCollection(product1).filterDate(ee.Date(nday),
#                                               ee.Date(ee.Number(nday).add(86400000))).filterBounds(region).select(band).first()

#     image2=ee.ImageCollection(product2).filterDate(ee.Date(nday),
#                                                    ee.Date(ee.Number(nday).add(86400000))).filterBounds(region).select(maskband).first()

#     image2=image2.bitwiseAnd((46851)).reproject(crs_mod,trans_mod)

#     return image.updateMask(image2.gt(0).And(image2.neq(3)).Not())

def selimage_wrapper(nday):
    # Define the necessary parameters
    product1 = 'MODIS/061/' + prod + '09GQ'
    product2 = 'MODIS/061/' + prod + '09GA'
    region = ee.Geometry.Rectangle([coords[0] - ray, coords[1] - ray,
                                    coords[0] + ray, coords[1] + ray])
    maskband = 'state_1km'
    band = ['sur_refl_b02', 'sur_refl_b01']
    crs_mod = 'EPSG:4326'  # Replace with actual CRS
    trans_mod = [1, 0, 0, 0, 1, 0]  # Replace with actual transform
    scale_mod = 1000  # Replace with actual scale

    # Call the selimage function with the defined parameters
    return selimage(nday, product1, product2, region, maskband, band, crs_mod, trans_mod)

# %%
def fetch_day(args):
    i, nday, product1, product2, region, maskband, band, crs_mod, trans_mod, scale_mod = args
    ee.Initialize(credentials)
    img = selimage(nday, product1, product2, region, maskband, band, crs_mod, trans_mod)
    res = ee.ImageCollection(img).getRegion(region, scale_mod).getInfo()
    arr = np.array(res)[1:,1:].astype(float)
    return i, arr

# %%
def getImages(name, lonlat, products, ray, save_path):

    for i in range(0,1):

        coords = lonlat[i] #Central area coordinates. NB coordstat should not be taken inside river since snow period selection is calculated there
        years = [2000, 2021] #Calibration period (has to be < 5000 days)

        gauge_name = name[i]
        gauge_lon = lonlat[i][0]
        gauge_lat = lonlat[i][1]

        #region = ee.Geometry.Point(coordstat).buffer(ray*100000).bounds()
        region = ee.Geometry.Rectangle([coords[0] - ray, coords[1] - ray,
                                      coords[0] + ray, coords[1] + ray])

        for prod in products:
            product1 = 'MODIS/061/' + prod + '09GQ';
            product2 = 'MODIS/061/' + prod + '09GA';

            datestartCAL = ee.Date(str(years[0]) + '-01-01').millis();
            dateendCAL = ee.Date(str(years[-1]) + '-12-31').millis();

            band = ['sur_refl_b02', 'sur_refl_b01'];

            coll = ee.ImageCollection(product1).filterDate(datestartCAL, dateendCAL).filterBounds(region).select(band);
            proj = coll.first().projection();
            scale_mod = ee.Number(proj.nominalScale()).getInfo()
            trans_mod = proj.getInfo()['transform'];
            crs_mod = proj.getInfo()['crs'];

            maskband = 'state_1km';

            # Reduce data size
            def calc_Date(image, llist):
                value = image.get('system:time_start')
                value = ee.Number(ee.Date(ee.List([value, -9999]).\
                                        reduce(ee.Reducer.firstNonNull())).millis());
                return ee.List(llist).add(value)

            def selection(image):
                date = image.get('system:time_start')
                im = image.select(maskband).reproject(crs_mod,trans_mod).bitwiseAnd((46851))
                image = image.select(band).updateMask(im.gt(0).And(im.neq(3)).Not())
                image = image.updateMask(image.gt(0))

                value = image.select(band[0]).mask().reduceRegion(**{'reducer':ee.Reducer.mean(),
                                                                     'geometry':region,
                                                                     'crs':crs_mod,
                                                                     'crsTransform':trans_mod,
                                                                     'bestEffort':True})
                value = ee.Number(value.get(value.keys().get(0)))
                return image.set('Valid_perc',value).set('system:time_start',date)


            coll2 = ee.ImageCollection(product2).filterDate(datestartCAL, dateendCAL).filterBounds(region).select(maskband
                                                                                                                 );
            coll = coll.combine(coll2)
            n = coll.size().getInfo()
            print('dimension premasking: ' + str(n))

            coll0 =coll.map(selection)
            coll0 = coll0.filterMetadata('Valid_perc', 'not_less_than', 0.20)
            first = ee.List([])
            dlistn = ee.List(coll0.iterate(calc_Date,first)).distinct().getInfo()
            dlistn = np.sort(dlistn).tolist()
            
            ##
            # selimage(nday=nday, product1=product1, product2=product2, region=region,
            #          maskband=maskband, band=band, crs_mod=crs_mod, trans_mod=transmod)

            # coll = ee.ImageCollection(ee.List(dlistn).map(selimage))
            coll = ee.ImageCollection(ee.List(dlistn).map(selimage_wrapper))


            n = coll.size().getInfo()

            print('dimension postmasking: ' + str(n))
            
#             def fetch_day(i_nday):
#                 i, nday = i_nday
#                 ee.Initialize(credentials)
#                 img = selimage(nday)
#                 res = ee.ImageCollection(img) \
#                          .getRegion(region, scale_mod) \
#                          .getInfo()

#                 arr = np.array(res)[1:, 1:].astype(float)

#                 return i, arr

            tic = time.time()

            args = [
                (i, nday, product1, product2, region, maskband, band, crs_mod, trans_mod, scale_mod)
                for i, nday in enumerate(dlistn)
            ]

            with Pool(processes=16) as pool:
                results = pool.map(fetch_day, args)

#             with Pool(processes=16) as pool:
#                 results = pool.map(fetch_day, list(enumerate(dlistn)))

            # with Pool(processes=16) as pool:
            #     results = pool.map(fetch_day, list(enumerate(dlistn)))

            toc = time.time()
            print('That took: ' + str(toc - tic))

            # Extract lon/lat just once
            llon = results[0][1][:, 0]
            llat = results[0][1][:, 1]

            # Setup for reshape
            n_pixels = len(llon)  # 5184
            nx = int(math.sqrt(n_pixels))
            ny = nx

            assert nx * ny == n_pixels, "Grid shape mismatch"

            # Extract time and bands
            ttime = np.empty(len(dlistn))
            surf2 = np.empty((n_pixels, len(dlistn)))
            surf1 = np.empty((n_pixels, len(dlistn)))

            for idx, arr in results:
                ttime[idx] = arr[0, 2]
                surf2[:, idx] = arr[:, 3]
                surf1[:, idx] = arr[:, 4]

            # Reshape
            llon = llon.reshape(ny, nx)
            llat = llat.reshape(ny, nx)

            surf2 = surf2.reshape(ny, nx, -1)
            surf1 = surf1.reshape(ny, nx, -1)

            # Make DataSet
            ds = xr.Dataset(
                data_vars={
                    'surf2': (('lat', 'lon', 'date'), surf2),
                    'surf1': (('lat', 'lon', 'date'), surf1),
                },
                coords={
                    'lon': (('lat', 'lon'), llon),
                    'lat': (('lat', 'lon'), llat),
                    'date': pd.to_datetime(ttime, unit='ms')
                }
            )

            # Add global attributes
            ds.attrs['Sttn_Nm'] = gauge_name
            ds.attrs['Sttn_lon'] = gauge_lon
            ds.attrs['Sttn_lat'] = gauge_lat

            # Save as netcdf
            ds.to_netcdf(os.path.join(save_path, gauge_name + '_'+ prod + '.nc'))

# %%
# ### This works outside of a function

# def getImages(name, lonlat, products, ray, save_path):

#     for i in range(0,1):

#         coords = lonlat[i] #Central area coordinates. NB coordstat should not be taken inside river since snow period selection is calculated there
#         years = [2000, 2021] #Calibration period (has to be < 5000 days)

#         gauge_name = name[i]
#         gauge_lon = lonlat[i][0]
#         gauge_lat = lonlat[i][1]

#         #region = ee.Geometry.Point(coordstat).buffer(ray*100000).bounds()
#         region = ee.Geometry.Rectangle([coords[0] - ray, coords[1] - ray,
#                                       coords[0] + ray, coords[1] + ray])

#         for prod in products:
#             product1 = 'MODIS/061/' + prod + '09GQ';
#             product2 = 'MODIS/061/' + prod + '09GA';

#             datestartCAL = ee.Date(str(years[0]) + '-01-01').millis();
#             dateendCAL = ee.Date(str(years[-1]) + '-12-31').millis();

#             band = ['sur_refl_b02', 'sur_refl_b01'];

#             coll = ee.ImageCollection(product1).filterDate(datestartCAL, dateendCAL).filterBounds(region).select(band);
#             proj = coll.first().projection();
#             scale_mod = ee.Number(proj.nominalScale()).getInfo()
#             trans_mod = proj.getInfo()['transform'];
#             crs_mod = proj.getInfo()['crs'];

#             maskband = 'state_1km';

#             # Reduce data size
#             def calc_Date(image, llist):
#                 value = image.get('system:time_start')
#                 value = ee.Number(ee.Date(ee.List([value, -9999]).\
#                                         reduce(ee.Reducer.firstNonNull())).millis());
#                 return ee.List(llist).add(value)

#             def selection(image):
#                 date = image.get('system:time_start')
#                 im = image.select(maskband).reproject(crs_mod,trans_mod).bitwiseAnd((46851))
#                 image = image.select(band).updateMask(im.gt(0).And(im.neq(3)).Not())
#                 image = image.updateMask(image.gt(0))

#                 value = image.select(band[0]).mask().reduceRegion(**{'reducer':ee.Reducer.mean(),
#                                                                      'geometry':region,
#                                                                      'crs':crs_mod,
#                                                                      'crsTransform':trans_mod,
#                                                                      'bestEffort':True})
#                 value = ee.Number(value.get(value.keys().get(0)))
#                 return image.set('Valid_perc',value).set('system:time_start',date)


#             coll2 = ee.ImageCollection(product2).filterDate(datestartCAL, dateendCAL).filterBounds(region).select(maskband
#                                                                                                                  );
#             coll = coll.combine(coll2)
#             n = coll.size().getInfo()
#             print('dimension premasking: ' + str(n))

#             coll0 =coll.map(selection)
#             coll0 = coll0.filterMetadata('Valid_perc', 'not_less_than', 0.20)
#             first = ee.List([])
#             dlistn = ee.List(coll0.iterate(calc_Date,first)).distinct().getInfo()
#             dlistn = np.sort(dlistn).tolist()

#             def selimage(nday):
#                 image=ee.ImageCollection(product1).filterDate(ee.Date(nday),
#                                                               ee.Date(ee.Number(nday).add(86400000))).filterBounds(region).select(band).first()

#                 image2=ee.ImageCollection(product2).filterDate(ee.Date(nday),
#                                                                ee.Date(ee.Number(nday).add(86400000))).filterBounds(region).select(maskband).first()

#                 image2=image2.bitwiseAnd((46851)).reproject(crs_mod,trans_mod)

#                 return image.updateMask(image2.gt(0).And(image2.neq(3)).Not())

#             coll = ee.ImageCollection(ee.List(dlistn).map(selimage))

#             n = coll.size().getInfo()

#             print('dimension postmasking: ' + str(n))
            
#             def fetch_day(i_nday):
#                 i, nday = i_nday
#                 ee.Initialize(credentials)
#                 img = selimage(nday)
#                 res = ee.ImageCollection(img) \
#                          .getRegion(region, scale_mod) \
#                          .getInfo()

#                 arr = np.array(res)[1:, 1:].astype(float)

#                 return i, arr

#                 tic = time.time()

#             with Pool(processes=16) as pool:
#                 results = pool.map(fetch_day, list(enumerate(dlistn)))

#             # with Pool(processes=16) as pool:
#             #     results = pool.map(fetch_day, list(enumerate(dlistn)))

#             toc = time.time()
#             print('That took: ' + str(toc - tic))

#             # Extract lon/lat just once
#             llon = results[0][1][:, 0]
#             llat = results[0][1][:, 1]

#             # Setup for reshape
#             n_pixels = len(llon)  # 5184
#             nx = int(math.sqrt(n_pixels))
#             ny = nx

#             assert nx * ny == n_pixels, "Grid shape mismatch"

#             # Extract time and bands
#             ttime = np.empty(len(dlistn))
#             surf2 = np.empty((n_pixels, len(dlistn)))
#             surf1 = np.empty((n_pixels, len(dlistn)))

#             for idx, arr in results:
#                 ttime[idx] = arr[0, 2]
#                 surf2[:, idx] = arr[:, 3]
#                 surf1[:, idx] = arr[:, 4]

#             # Reshape
#             llon = llon.reshape(ny, nx)
#             llat = llat.reshape(ny, nx)

#             surf2 = surf2.reshape(ny, nx, -1)
#             surf1 = surf1.reshape(ny, nx, -1)

#             # Make DataSet
#             ds = xr.Dataset(
#                 data_vars={
#                     'surf2': (('lat', 'lon', 'date'), surf2),
#                     'surf1': (('lat', 'lon', 'date'), surf1),
#                 },
#                 coords={
#                     'lon': (('lat', 'lon'), llon),
#                     'lat': (('lat', 'lon'), llat),
#                     'date': pd.to_datetime(ttime, unit='ms')
#                 }
#             )

#             # Add global attributes
#             ds.attrs['Sttn_Nm'] = gauge_name
#             ds.attrs['Sttn_lon'] = gauge_lon
#             ds.attrs['Sttn_lat'] = gauge_lat

#             # Save as netcdf
#             ds.to_netcdf(os.path.join(save_path, gauge_name + '_'+ prod + '.nc'))

# %% [markdown]
# ### Setup

# %%
ee.Authenticate()
# Out:
# True

# %%
folderGEE = 'projects/MODIS-discharge'
user ='fbennitt'
service_account = 'modis-discharge@modis-discharge.iam.gserviceaccount.com'
key = '/home/fbennitt_umass_edu/modis-discharge-411743fe59a9.json'

# %%
credentials = ee.ServiceAccountCredentials(service_account, key)

# %%
ee.Initialize(credentials)

# %%
save_path = '/nas/cee-water/cjgleason/data/MODIS/'

# %%
products = ['MOD','MYD']
ray = 0.075

# %% [markdown]
# ### Extract metadata

# %%
file = pd.read_parquet('/nas/cee-water/cjgleason/fiona/MODIS_discharge/data/gauges_sampled.parquet')

# %%
name = file['Sttn_Nm'].to_list()
lon = file['lon'].to_list()
lat = file['lat'].to_list()
lonlat = list(zip(lon, lat))

# %% [markdown]
# ### Download data

# %%
save_path = '/nas/cee-water/cjgleason/data/MODIS/bands_1_2_masked_2025_06_23/'

# %%
getImages(name=name, lonlat=lonlat, products=products, ray=ray, save_path=save_path)
# Out:
# dimension premasking: 7925
# dimension postmasking: 1738
# That took: 50.03825879096985
# dimension premasking: 7110
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# File /work/pi_cjgleason_umass_edu/.conda/envs/modisQ/lib/python3.12/site-packages/ee/data.py:408, in _execute_cloud_call(call, num_retries)
#     407 try:
# --> 408   return call.execute(num_retries=num_retries)
#     409 except googleapiclient.errors.HttpError as e:
#
# File /work/pi_cjgleason_umass_edu/.conda/envs/modisQ/lib/python3.12/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File /work/pi_cjgleason_umass_edu/.conda/envs/modisQ/lib/python3.12/site-packages/googleapiclient/http.py:938, in HttpRequest.execute(self, http, num_retries)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1/projects/earthengine-legacy/value:compute?prettyPrint=false&alt=json returned "Image.bitwiseAnd: Parameter 'image1' is required and may not be null.". Details: "Image.bitwiseAnd: Parameter 'image1' is required and may not be null.">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 getImages(name=name, lonlat=lonlat, products=products, ray=ray, save_path=save_path)
#
# Cell In[86], line 75, in getImages(name, lonlat, products, ray, save_path)
#      67             ##
#      68             # selimage(nday=nday, product1=product1, product2=product2, region=region,
#      69             #          maskband=maskband, band=band, crs_mod=crs_mod, trans_mod=transmod)
#      70
#      71             # coll = ee.ImageCollection(ee.List(dlistn).map(selimage))
#      72             coll = ee.ImageCollection(ee.List(dlistn).map(selimage_wrapper))
# ---> 75             n = coll.size().getInfo()
#      77             print('dimension postmasking: ' + str(n))
#      79 #             def fetch_day(i_nday):
#      80 #                 i, nday = i_nday
#      81 #                 ee.Initialize(credentials)
#    (...)     88
#      89 #                 return i, arr
#
# File /work/pi_cjgleason_umass_edu/.conda/envs/modisQ/lib/python3.12/site-packages/ee/computedobject.py:107, in ComputedObject.getInfo(self)
#     101 def getInfo(self) -> Optional[Any]:
#     102   """Fetch and return information about this object.
#     103
#     104   Returns:
#     105     The object can evaluate to anything.
#     106   """
# --> 107   return data.computeValue(self)
#
# File /work/pi_cjgleason_umass_edu/.conda/envs/modisQ/lib/python3.12/site-packages/ee/data.py:1128, in computeValue(obj)
#    1125 body = {'expression': serializer.encode(obj, for_cloud_api=True)}
#    1126 _maybe_populate_workload_tag(body)
# -> 1128 return _execute_cloud_call(
#    1129     _get_cloud_projects()
#    1130     .value()
#    1131     .compute(body=body, project=_get_projects_path(), prettyPrint=False)
#    1132 )['result']
#
# File /work/pi_cjgleason_umass_edu/.conda/envs/modisQ/lib/python3.12/site-packages/ee/data.py:410, in _execute_cloud_call(call, num_retries)
#     408   return call.execute(num_retries=num_retries)
#     409 except googleapiclient.errors.HttpError as e:
# --> 410   raise _translate_cloud_exception(e)
#
# EEException: Image.bitwiseAnd: Parameter 'image1' is required and may not be null.

# %% [markdown]
# ### Debugging

# %%
i = 0

# %%
coords = lonlat[i] #Central area coordinates. NB coordstat should not be taken inside river since snow period selection is calculated there
years = [2000, 2021] #Calibration period (has to be < 5000 days)

gauge_name = name[i]
gauge_lon = lonlat[i][0]
gauge_lat = lonlat[i][1]

#region = ee.Geometry.Point(coordstat).buffer(ray*100000).bounds()
region = ee.Geometry.Rectangle([coords[0] - ray, coords[1] - ray,
                                coords[0] + ray, coords[1] + ray])

# %%
prod = products[0]

# %%
product1 = 'MODIS/061/' + prod + '09GQ';
product2 = 'MODIS/061/' + prod + '09GA';

datestartCAL = ee.Date(str(years[0]) + '-01-01').millis();
dateendCAL = ee.Date(str(years[-1]) + '-12-31').millis();

band = ['sur_refl_b02', 'sur_refl_b01'];

coll = ee.ImageCollection(product1).filterDate(datestartCAL, dateendCAL).filterBounds(region).select(band);
proj = coll.first().projection();
scale_mod = ee.Number(proj.nominalScale()).getInfo()
trans_mod = proj.getInfo()['transform'];
crs_mod = proj.getInfo()['crs'];

maskband = 'state_1km';

# %%
# Reduce data size
def calc_Date(image, llist):
    value = image.get('system:time_start')
    value = ee.Number(ee.Date(ee.List([value, -9999]).\
                            reduce(ee.Reducer.firstNonNull())).millis());
    return ee.List(llist).add(value)

def selection(image):
    date = image.get('system:time_start')
    im = image.select(maskband).reproject(crs_mod,trans_mod).bitwiseAnd((46851))
    image = image.select(band).updateMask(im.gt(0).And(im.neq(3)).Not())
    image = image.updateMask(image.gt(0))

    value = image.select(band[0]).mask().reduceRegion(**{'reducer':ee.Reducer.mean(),
                                                         'geometry':region,
                                                         'crs':crs_mod,
                                                         'crsTransform':trans_mod,
                                                         'bestEffort':True})
    value = ee.Number(value.get(value.keys().get(0)))
    return image.set('Valid_perc',value).set('system:time_start',date)

# %%
coll2 = ee.ImageCollection(product2).filterDate(datestartCAL, dateendCAL).filterBounds(region).select(maskband
                                                                                                     );
coll = coll.combine(coll2)
n = coll.size().getInfo()
print('dimension premasking: ' + str(n))

coll0 =coll.map(selection)
coll0 = coll0.filterMetadata('Valid_perc', 'not_less_than', 0.20)
first = ee.List([])
dlistn = ee.List(coll0.iterate(calc_Date,first)).distinct().getInfo()
dlistn = np.sort(dlistn).tolist()
# Out:
# dimension premasking: 7925

# %%
def selimage(nday):
    image=ee.ImageCollection(product1).filterDate(ee.Date(nday),
                                                  ee.Date(ee.Number(nday).add(86400000))).filterBounds(region).select(band).first()

    image2=ee.ImageCollection(product2).filterDate(ee.Date(nday),
                                                   ee.Date(ee.Number(nday).add(86400000))).filterBounds(region).select(maskband).first()

    image2=image2.bitwiseAnd((46851)).reproject(crs_mod,trans_mod)

    return image.updateMask(image2.gt(0).And(image2.neq(3)).Not())

# %%
coll = ee.ImageCollection(ee.List(dlistn).map(selimage))

n = coll.size().getInfo()

print('dimension postmasking: ' + str(n))
# Out:
# dimension postmasking: 1738

# %%
def fetch_day(i_nday):
    i, nday = i_nday
    ee.Initialize(credentials)
    img = selimage(nday)
    # arr = np.array(img.getRegion(region, scale_mod).getInfo())[1:,1:].astype(float)
    
    # client_feat = img.rename('bands')  # optional: rename for familiarity
    res = ee.ImageCollection(img) \
             .getRegion(region, scale_mod) \
             .getInfo()

    arr = np.array(res)[1:, 1:].astype(float)

    return i, arr

# %%
tic = time.time()

with Pool(processes=16) as pool:
    results = pool.map(fetch_day, list(enumerate(dlistn)))

# with Pool(processes=16) as pool:
#     results = pool.map(fetch_day, list(enumerate(dlistn)))

toc = time.time()
print('That took: ' + str(toc - tic))
# Out:
# That took: 51.37319850921631

# %%
# Extract lon/lat just once
llon = results[0][1][:, 0]
llat = results[0][1][:, 1]

# Setup for reshape
n_pixels = len(llon)  # 5184
nx = int(math.sqrt(n_pixels))
ny = nx

assert nx * ny == n_pixels, "Grid shape mismatch"

# Extract time and bands
ttime = np.empty(len(dlistn))
surf2 = np.empty((n_pixels, len(dlistn)))
surf1 = np.empty((n_pixels, len(dlistn)))

for idx, arr in results:
    ttime[idx] = arr[0, 2]
    surf2[:, idx] = arr[:, 3]
    surf1[:, idx] = arr[:, 4]

# Reshape
llon = llon.reshape(ny, nx)
llat = llat.reshape(ny, nx)

surf2 = surf2.reshape(ny, nx, -1)
surf1 = surf1.reshape(ny, nx, -1)

# Make DataSet
ds = xr.Dataset(
    data_vars={
        'surf2': (('lat', 'lon', 'date'), surf2),
        'surf1': (('lat', 'lon', 'date'), surf1),
    },
    coords={
        'lon': (('lat', 'lon'), llon),
        'lat': (('lat', 'lon'), llat),
        'date': pd.to_datetime(ttime, unit='ms')
    }
)

# Add global attributes
ds.attrs['Sttn_Nm'] = gauge_name
ds.attrs['Sttn_lon'] = gauge_lon
ds.attrs['Sttn_lat'] = gauge_lat

# %%
ds["surf2"].isel(date=5).plot(
    x="lon", y="lat", cmap="Greys_r", figsize=(8, 6), robust=True
)

# %%
# Save as netcdf
ds.to_netcdf(os.path.join(save_path, gauge_name + '_'+ prod + '.nc'))

# %%
llon = MOD[:, 0, 0]
llat = MOD[:, 1, 0]

time = MOD[0, 2, :]

surf2 = MOD[:, 3, :]
surf1 = MOD[:, 4, :]

# %%
n_pixels = len(llon)  # 5184
nx = int(math.sqrt(n_pixels))
ny = nx  # if square grid

assert nx * ny == n_pixels, "Grid shape mismatch"

# %%
lon2d = llon.reshape(ny, nx)
lat2d = llat.reshape(ny, nx)

surf2_grid = surf2.reshape(ny, nx, -1)  # time axis stays last
surf1_grid = surf1.reshape(ny, nx, -1)

# %%
surf2_grid.shape
# Out:
# (72, 72, 6)

# %%
ds_grid = xr.Dataset(
    data_vars={
        # 'station_name': gauge_name,
        'surf2': (('lat', 'lon', 'date'), surf2_grid),
        'surf1': (('lat', 'lon', 'date'), surf1_grid),
    },
    coords={
        'lon': (('lat', 'lon'), lon2d),
        'lat': (('lat', 'lon'), lat2d),
        'date': pd.to_datetime(time, unit='ms')
    }
)

# %%
ds_grid.attrs['Sttn_Nm'] = gauge_name
ds_grid.attrs['Sttn_lon'] = gauge_lon
ds_grid.attrs['Sttn_lat'] = gauge_lat

# %%
ds_grid
# Out:
# <xarray.Dataset> Size: 581kB
# Dimensions:  (lat: 72, lon: 72, date: 6)
# Coordinates:
#     lon      (lat, lon) float64 41kB 18.51 18.51 18.51 ... 18.65 18.66 18.66
#     lat      (lat, lon) float64 41kB 4.292 4.292 4.292 4.292 ... 4.44 4.44 4.44
#   * date     (date) datetime64[ns] 48B 2000-02-29 2000-03-01 ... 2000-03-07
# Data variables:
#     surf2    (lat, lon, date) float64 249kB 2.245e+03 1.861e+03 ... 2.366e+03
#     surf1    (lat, lon, date) float64 249kB 1.237e+03 955.0 nan ... 506.0 980.0
# Attributes:
#     Sttn_Nm:  1749100_GRDC

# %%
ds_grid['lon'].max() - ds_grid['lon'].min()
# Out:
# <xarray.DataArray 'lon' ()> Size: 8B
# array(0.14775132)

# %%
ds_grid['lat'].max() - ds_grid['lat'].min()
# Out:
# <xarray.DataArray 'lat' ()> Size: 8B
# array(0.14775132)

# %%
ds_grid["surf2"].isel(date=5).plot(
    x="lon", y="lat", cmap="Greys_r", figsize=(8, 6), robust=True
)

# %%
ds = xr.Dataset(
    data_vars={
        'surf2': (('pixels', 'time'), surf2),
        'surf1': (('pixels', 'time'), surf1),
    },
    coords={
        'pixels': np.arange(len(llon)),
        'lon': ('pixels', llon),
        'lat': ('pixels', llat),
        'date': pd.to_datetime(time)
    }
)

# %%
ds
# Out:
# <xarray.Dataset> Size: 622kB
# Dimensions:  (pixels: 5184, time: 6, date: 6)
# Coordinates:
#   * pixels   (pixels) int64 41kB 0 1 2 3 4 5 6 ... 5178 5179 5180 5181 5182 5183
#     lon      (pixels) float64 41kB 18.51 18.51 18.51 18.52 ... 18.65 18.66 18.66
#     lat      (pixels) float64 41kB 4.292 4.292 4.292 4.292 ... 4.44 4.44 4.44
#   * date     (date) datetime64[ns] 48B 1970-01-01T00:15:51.782400 ... 1970-01...
# Dimensions without coordinates: time
# Data variables:
#     surf2    (pixels, time) float64 249kB 2.245e+03 1.861e+03 ... 2.366e+03
#     surf1    (pixels, time) float64 249kB 1.237e+03 955.0 nan ... 506.0 980.0

# %%
# Convert the array to a pandas DataFrame
df = pd.DataFrame(MOD[1:, :, :], columns=MOD[0, :, :])

# Convert the 'time' column to datetime objects
df['time'] = pd.to_datetime(df['time'], unit='ms')

df['sur_refl_b01'] = df['sur_refl_b01'].astype(float)

df = df.set_index(['longitude', 'latitude', 'time'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 2
#       1 # Convert the array to a pandas DataFrame
# ----> 2 df = pd.DataFrame(MOD[1:, :, :], columns=MOD[0, :, :])
#       4 # Convert the 'time' column to datetime objects
#       5 df['time'] = pd.to_datetime(df['time'], unit='ms')
#
# File /work/pi_cjgleason_umass_edu/.conda/envs/modisQ/lib/python3.12/site-packages/pandas/core/frame.py:827, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     816         mgr = dict_to_mgr(
#     817             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     818             # attribute "name"
#    (...)    824             copy=_copy,
#     825         )
#     826     else:
# --> 827         mgr = ndarray_to_mgr(
#     828             data,
#     829             index,
#     830             columns,
#     831             dtype=dtype,
#     832             copy=copy,
#     833             typ=manager,
#     834         )
#     836 # For data is list-like, or Iterable (will consume into list)
#     837 elif is_list_like(data):
#
# File /work/pi_cjgleason_umass_edu/.conda/envs/modisQ/lib/python3.12/site-packages/pandas/core/internals/construction.py:314, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     312     else:
#     313         values = np.asarray(values)
# --> 314     values = _ensure_2d(values)
#     316 else:
#     317     # by definition an array here
#     318     # the dtypes will be coerced to a single dtype
#     319     values = _prep_ndarraylike(values, copy=copy_on_sanitize)
#
# File /work/pi_cjgleason_umass_edu/.conda/envs/modisQ/lib/python3.12/site-packages/pandas/core/internals/construction.py:592, in _ensure_2d(values)
#     590     values = values.reshape((values.shape[0], 1))
#     591 elif values.ndim != 2:
# --> 592     raise ValueError(f"Must pass 2-d input. shape={values.shape}")
#     593 return values
#
# ValueError: Must pass 2-d input. shape=(5183, 5, 6)

# %%
ds = df.to_xarray()

# %%
ds
# Out:
# <xarray.Dataset> Size: 126kB
# Dimensions:       (longitude: 72, latitude: 72, time: 1)
# Coordinates:
#   * longitude     (longitude) float64 576B 18.51 18.51 18.51 ... 18.66 18.66
#   * latitude      (latitude) float64 576B 4.292 4.294 4.296 ... 4.436 4.438 4.44
#   * time          (time) datetime64[ns] 8B 2002-07-09
# Data variables:
#     id            (longitude, latitude, time) object 41kB '2002_07_09' ... '2...
#     sur_refl_b01  (longitude, latitude, time) float64 41kB 465.0 465.0 ... nan
#     sur_refl_b02  (longitude, latitude, time) object 41kB 3628 3628 ... None

# %%
ds['sur_refl_b01'].plot()

# %%
# def getImages(name, lonlat, products, ray, save_path):

#     for i in range(0,1):

#         coords = lonlat[i] #Central area coordinates. NB coordstat should not be taken inside river since snow period selection is calculated there
#         years = [2000, 2021] #Calibration period (has to be < 5000 days)

#         gauge_name = name[i]
#         gauge_lon = lonlat[i][0]
#         gauge_lat = lonlat[i][1]

#         #region = ee.Geometry.Point(coordstat).buffer(ray*100000).bounds()
#         region = ee.Geometry.Rectangle([coords[0] - ray, coords[1] - ray,
#                                       coords[0] + ray, coords[1] + ray])

#         for prod in products:
#             product1 = 'MODIS/061/' + prod + '09GQ';
#             product2 = 'MODIS/061/' + prod + '09GA';

#             datestartCAL = ee.Date(str(years[0]) + '-01-01').millis();
#             dateendCAL = ee.Date(str(years[-1]) + '-12-31').millis();

#             band = ['sur_refl_b02', 'sur_refl_b01'];

#             coll = ee.ImageCollection(product1).filterDate(datestartCAL, dateendCAL).filterBounds(region).select(band);
#             proj = coll.first().projection();
#             scale_mod = ee.Number(proj.nominalScale()).getInfo()
#             trans_mod = proj.getInfo()['transform'];
#             crs_mod = proj.getInfo()['crs'];

#             maskband = 'state_1km';
            
#             # Reduce data size
#             def calc_Date(image, llist):
#                 value = image.get('system:time_start')
#                 value = ee.Number(ee.Date(ee.List([value, -9999]).\
#                                         reduce(ee.Reducer.firstNonNull())).millis());
#                 return ee.List(llist).add(value)
            
#             def selection(image):
#                 date = image.get('system:time_start')
#                 im = image.select(maskband).reproject(crs_mod,trans_mod).bitwiseAnd((46851))
#                 image = image.select(band).updateMask(im.gt(0).And(im.neq(3)).Not())
#                 image = image.updateMask(image.gt(0))

#                 value = image.select(band[0]).mask().reduceRegion(**{'reducer':ee.Reducer.mean(),
#                                                                      'geometry':region,
#                                                                      'crs':crs_mod,
#                                                                      'crsTransform':trans_mod,
#                                                                      'bestEffort':True})
#                 value = ee.Number(value.get(value.keys().get(0)))
#                 return image.set('Valid_perc',value).set('system:time_start',date)


#             coll2 = ee.ImageCollection(product2).filterDate(datestartCAL, dateendCAL).filterBounds(region).select(maskband
#                                                                                                                  );
#             coll = coll.combine(coll2)
#             n = coll.size().getInfo()
#             print('dimension premasking: ' + str(n))

#             coll0 =coll.map(selection)
#             coll0 = coll0.filterMetadata('Valid_perc', 'not_less_than', 0.20)
#             first = ee.List([])
#             dlistn = ee.List(coll0.iterate(calc_Date,first)).distinct().getInfo()
#             dlistn = np.sort(dlistn).tolist()
            
#             def selimage(nday):
#                 image=ee.ImageCollection(product1).filterDate(ee.Date(nday),
#                                                               ee.Date(ee.Number(nday).add(86400000))).filterBounds(region).select(band).first()
                
#                 image2=ee.ImageCollection(product2).filterDate(ee.Date(nday),
#                                                                ee.Date(ee.Number(nday).add(86400000))).filterBounds(region).select(maskband).first()
                
#                 image2=image2.bitwiseAnd((46851)).reproject(crs_mod,trans_mod)

#                 return image.updateMask(image2.gt(0).And(image2.neq(3)).Not())

#             coll = ee.ImageCollection(ee.List(dlistn).map(selimage))

#             n = coll.size().getInfo()

#             print('dimension postmasking: '+ str(n))

#             MOD0 = np.array(ee.ImageCollection(coll.first()).select(band).getRegion(region, scale_mod).getInfo())

#             MOD = np.zeros([np.shape(MOD0)[0]-1, 5, n])

#             def fetch_single_day(args):
#                 idx, nday, region, product1, product2, band, crs_mod, trans_mod, scale_mod = args
#                 ee.Initialize(opt_url="https://earthengine-highvolume.googleapis.com")
#                 for att in range(3):
#                     try:
#                         img = selimage(nday)
#                         arr = np.array(img.getRegion(region, scale_mod).getInfo())[1:,1:].astype(float)
#                         return idx, arr
#                     except Exception as e:
#                         if att == 2:
#                             raise
#                 return idx, None
            
#             # Prepare arguments for all days
#             args = [
#                 (
#                     i, nday,
#                     region, product1, product2,
#                     band, crs_mod, trans_mod, scale_mod
#                 )
#                 for i, nday in enumerate(dlistn)
#             ]

#             # MOD = np.zeros([n_pixels, 5, len(dlistn)])

#             with Pool(processes=16) as pool:  # adjust to your HPC's capacity
#                 for idx, arr in pool.imap_unordered(fetch_single_day, args):
#                     MOD[:,:,idx] = arr


# #             start = time.time()
# #             for i in range(n):
# #                 print('reading image ' + str(i) + ' of ' + str(n))
# #                 tic=time.time()
# #                 ee.Initialize(credentials)

# #                 nn=0
# #                 while nn<3:
# #                     try:
# #                         nn+=1
# #                         coll0=ee.ImageCollection(ee.Image(ee.List(coll.toList(n)).get(i)))
# #                         arr=np.array(coll0.getRegion(region, scale_mod).getInfo())
# #                         arr=arr[1:,1:].astype(float)                
# #                         MOD[:,:,i]=arr
# #                     finally:
# #                         nn=4
# #                 toc=time.time()
# #                 print(toc-tic)
# #             end = time.time()
# #             print('That took ' + (end-start))

            

#             # Extract components
#             llon = MOD[:, 0, 0]
#             llat = MOD[:, 1, 0]
#             ttime = MOD[0, 2, :]
#             surf2 = MOD[:, 3, :]
#             surf1 = MOD[:, 4, :]

#             n_pixels = len(llon)  # 5184
#             nx = int(math.sqrt(n_pixels))
#             ny = nx

#             assert nx * ny == n_pixels, "Grid shape mismatch"

#             # Reshape
#             llon = llon.reshape(ny, nx)
#             llat = llat.reshape(ny, nx)

#             surf2 = surf2.reshape(ny, nx, -1)
#             surf1 = surf1.reshape(ny, nx, -1)

#             # Make DataSet
#             ds = xr.Dataset(
#                 data_vars={
#                     'surf2': (('lat', 'lon', 'date'), surf2_grid),
#                     'surf1': (('lat', 'lon', 'date'), surf1_grid),
#                 },
#                 coords={
#                     'lon': (('lat', 'lon'), lon2d),
#                     'lat': (('lat', 'lon'), lat2d),
#                     'date': pd.to_datetime(ttime, unit='ms')
#                 }
#             )

#             # Add global attributes
#             ds_grid.attrs['Sttn_Nm'] = gauge_name
#             ds_grid.attrs['Sttn_lon'] = gauge_lon
#             ds_grid.attrs['Sttn_lat'] = gauge_lat

#             # Save as netcdf
#             ds.to_netcdf(os.path.join(save_path, gauge_name + '_'+ prod + '.nc'))
