# %%
import os

import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.io as sio

# from mat73 import loadmat

# %%
data_path = '/nas/cee-water/cjgleason/data/Riggs_gauges/'

# %%
gauges = gpd.read_file(os.path.join(data_path, 'gauges.shp'))

# %%
gauges['lon'] = gauges.geometry.x
gauges['lat'] = gauges.geometry.y

# %%
gauges[gauges['meanQ'] >= 300]
# Out:
#              Sttn_Nm   start     end    obs  missed       meanQ  added  \
# 34     01015000_USGS  1908.0  1928.0   7458       0  409.831657    NaN
# 93     01034500_USGS  1902.0  2021.0  43457       0  345.960983    NaN
# 96     01036000_USGS  1938.0  1958.0   7267       0  345.394025    NaN
# 97     01036390_USGS  1979.0  1996.0   6388       0  404.976355    NaN
# 583    01170500_USGS  1904.0  2021.0  42910       0  406.159086    NaN
# ...              ...     ...     ...    ...     ...         ...    ...
# 45679      N.10A_RID  1980.0  1999.0   5359    1855  331.450774  308.0
# 45682      N.14A_RID  1980.0  1999.0   3107    4107  369.643482  365.0
# 45699       N.37_RID  1980.0  1996.0    640    5479  621.733906    NaN
# 45706       N.4A_RID  1980.0  1983.0    730     365  358.385753    NaN
# 45715        N.8_RID  1980.0  1999.0   3562    3652  324.664351  335.0
#
#             kge      rbias       rrmse  ...   val     distance  model  \
# 34          NaN        NaN         NaN  ...   NaN          NaN   None
# 93          NaN        NaN         NaN  ...   NaN          NaN   None
# 96          NaN        NaN         NaN  ...   NaN          NaN   None
# 97          NaN        NaN         NaN  ...   NaN          NaN   None
# 583         NaN        NaN         NaN  ...   NaN          NaN   None
# ...         ...        ...         ...  ...   ...          ...    ...
# 45679  0.610946 -17.028916   60.563107  ...  31.0 -2393.852805     hg
# 45682  0.742379 -18.426738   66.074024  ...  27.0  2184.128260     hg
# 45699       NaN        NaN         NaN  ...   NaN          NaN   None
# 45706       NaN        NaN         NaN  ...   NaN          NaN   None
# 45715  0.360498  -8.006307  108.631634  ...  32.0  1604.726916     hg
#
#               node_id      continent          a         b  \
# 34               None  North America        NaN       NaN
# 93               None  North America        NaN       NaN
# 96               None  North America        NaN       NaN
# 97               None  North America        NaN       NaN
# 583              None  North America        NaN       NaN
# ...               ...            ...        ...       ...
# 45679  44306700070161           Asia   7.101031  0.373146
# 45682  44306700010221           Asia   7.809382  0.430837
# 45699            None           Asia        NaN       NaN
# 45706            None           Asia        NaN       NaN
# 45715  44306700040151           Asia  15.055240  0.256112
#
#                          geometry         lon        lat
# 34     POINT (-67.93117 47.15981)  -67.931169  47.159806
# 93     POINT (-68.65139 45.23611)  -68.651389  45.236111
# 96     POINT (-68.62349 45.18258)  -68.623489  45.182581
# 97     POINT (-68.69667 44.82667)  -68.696667  44.826667
# 583     POINT (-72.5745 42.58022)  -72.574500  42.580222
# ...                           ...         ...        ...
# 45679  POINT (100.41694 16.21167)  100.416944  16.211667
# 45682  POINT (100.30944 15.89889)  100.309444  15.898889
# 45699  POINT (100.25972 15.75528)  100.259722  15.755278
# 45706  POINT (101.08139 17.28278)  101.081389  17.282778
# 45715  POINT (100.38139 16.03056)  100.381389  16.030556
#
# [1671 rows x 22 columns]

# %%
gauges['continent'].unique()
# Out:
# array(['Oceania', 'South America', 'North America', 'Asia', 'Europe',
#        'Africa'], dtype=object)

# %%
gauges_sampled = gauges[(gauges['end'] >= 2000) & (gauges['meanQ'] >= 300)].groupby(by='continent').sample(n=2, random_state=0).reset_index()

# %%
# gauges_sampled = gauges[gauges['end'] >= 2000].gropsample(n=10, random_state=0)

# %%
fig, ax = plt.subplots(figsize=(12,8))
gauges[gauges['end'] >= 2000].plot(markersize=0.25, ax=ax, color='cornflowerblue')
# gauges[(gauges['end'] >= 2000) & (gauges['meanQ'] >= 300)].plot(markersize=0.25, ax=ax, color='red')
# plt.xlim(-150, -50)
# plt.ylim(20, 60)
gauges_sampled.plot(markersize=3, ax=ax, color='red')
# Out:
# <Axes: >

# %%
gauges_sampled = gauges_sampled[['Sttn_Nm', 'start', 'end', 'obs',
                                 'missed', 'continent', 'lon', 'lat']]

# %%
gauges_sampled
# Out:
#            Sttn_Nm   start     end    obs  missed      continent         lon  \
# 0     1134250_GRDC  1925.0  2001.0  18333    9546         Africa   -6.050000
# 1     1834110_GRDC  1984.0  2002.0   6269     639         Africa    4.133300
# 2    1598_In_IWRIS  1978.0  2020.0  14958     570           Asia   78.347500
# 3   3157_arcticnet  1934.0  2002.0  20326    4662           Asia  116.800000
# 4     6242501_GRDC  1996.0  2017.0   8036       0         Europe   16.343750
# 5     6729311_GRDC  2004.0  2019.0   3677    1948         Europe   10.007267
# 6     4147461_GRDC  1904.0  2020.0  42553       0  North America  -72.574500
# 7    12453700_USGS  1960.0  2021.0  22245       5  North America -120.302297
# 8     5868050_GRDC  1959.0  2020.0  20974    1432        Oceania  169.323900
# 9      8091048_BOM  1994.0  2002.0   1355    1562        Oceania  128.498464
# 10    15326000_ANA  1988.0  2020.0  11736     244  South America  -65.527500
# 11    48290000_ANA  1946.0  2021.0  27166      58  South America  -39.823900
#
#           lat
# 0   13.716700
# 1   11.383300
# 2   22.915833
# 3   60.170000
# 4   48.360416
# 5   59.752922
# 6   42.578700
# 7   47.524293
# 8  -45.199500
# 9  -15.595237
# 10  -9.784700
# 11  -8.809700

# %%
save_path = '/nas/cee-water/cjgleason/fiona/MODIS_discharge/data'

# %%
gauges_sampled.to_parquet(os.path.join(save_path,
                                       'gauges_sampled.parquet'))

# %%
mat_data = sio.loadmat('/nas/cee-water/cjgleason/fiona/MODIS_discharge/data/gauges_sampled.mat')

# %%
mat_data['Sttn_Nm'][0][0]
# Out:
# array(['1196175_GRDC'], dtype='<U12')

# %%
def getFiles(filepath):
    files = []
    for file in os.listdir(data_path):
        if not file.startswith('.') and not file.endswith('.zip'):
            files.append(os.path.join(data_path, file))
    return files

# %%
def filterFiles(files, date):
    
    files_aqua = []
    
    for file in files:
        # read in
        df = pd.read_csv(file).reset_index()
        # set correct column names, drop row 0
        df.columns = df.iloc[0]
        df = df.iloc[1:]
        # make date object
        df['date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])
        filtered = df[df['date'] >= date]
        
        if filtered.shape[0] != 0:
            files_aqua.append(file)
        
    return files_aqua

# %%
files = getFiles(data_path)

# %%
files_aqua = filterFiles(files=files, date='2002-07-04')

# %%
test.columns = test.iloc[0]

# %%
test = test.iloc[1:]

# %%
test['date'] = pd.to_datetime(test[['Year', 'Month', 'Day']])
# Out:
# /tmp/ipykernel_3768475/3608695399.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['date'] = pd.to_datetime(test[['Year', 'Month', 'Day']])

# %%
test[test['date'] >= '2002-07-04']
# Out:
# 0      Year Month Day Discharge (m^3/s)       date
# 8036   2005     6   3                 0 2005-06-03
# 8037   2005     6   4                 0 2005-06-04
# 8038   2005     6   5                 0 2005-06-05
# 8039   2005     6   6                 0 2005-06-06
# 8040   2005     6   7                 0 2005-06-07
# ...     ...   ...  ..               ...        ...
# 13972  2021     9   3                 0 2021-09-03
# 13973  2021     9   4                 0 2021-09-04
# 13974  2021     9   5                 0 2021-09-05
# 13975  2021     9   6                 0 2021-09-06
# 13976  2021     9   7                 0 2021-09-07
#
# [5941 rows x 5 columns]

# %%
test.iloc[1:,0:3]
# Out:
#       index Latitude: -22.910194  Longitude: 139.915972
# 1      1966                   10                      1
# 2      1966                   10                      2
# 3      1966                   10                      3
# 4      1966                   10                      4
# 5      1966                   10                      5
# ...     ...                  ...                    ...
# 13972  2021                    9                      3
# 13973  2021                    9                      4
# 13974  2021                    9                      5
# 13975  2021                    9                      6
# 13976  2021                    9                      7
#
# [13976 rows x 3 columns]

# %%
np.array(test['index'][1:].astype(int))
# Out:
# array([1966, 1966, 1966, ..., 2021, 2021, 2021])
